# %%
import os
from dotenv import load_dotenv
load_dotenv()

ML_Summer_School_ID = os.getenv('ML_Summer_School_ID')
print("Your Sudent ID is: " + ML_Summer_School_ID)
# Out:
# Your Sudent ID is: Ml016_pyi_soe_khant

# %%
import numpy as np
import matplotlib.pyplot as plt
npy_path = f"./data_dataset_voc/SegmentationClassNpy/{ML_Summer_School_ID}.npy"

# Load the segmentation mask
mask = np.load(npy_path)  # shape: (H, W)
print(mask.shape)
plt.imshow(mask,cmap='jet')
# Out:
# (300, 300)

# %%
pip install imgviz
# Out:
# Collecting imgviz
#   Using cached imgviz-1.7.6-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: matplotlib in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from imgviz) (3.10.3)
# Requirement already satisfied: numpy in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from imgviz) (2.2.6)
# Requirement already satisfied: pillow>=5.3.0 in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from imgviz) (11.3.0)
# Collecting pyyaml (from imgviz)
#   Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from matplotlib->imgviz) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from matplotlib->imgviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from matplotlib->imgviz) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from matplotlib->imgviz) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from matplotlib->imgviz) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from matplotlib->imgviz) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from matplotlib->imgviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/pyisoekhant/.local/share/virtualenvs/Practical-ML-by-WAI-k1EFM13E/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->imgviz) (1.17.0)
# Using cached imgviz-1.7.6-py3-none-any.whl (7.7 MB)
# Using cached PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
# Installing collected packages: pyyaml, imgviz
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [imgviz]
# Successfully installed imgviz-1.7.6 pyyaml-6.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import imgviz
import cv2

# Load original image (from JPEGImages/)
img_path = f"./data_dataset_voc/JPEGImages/{ML_Summer_School_ID}.jpg"

class_path = f"./data_dataset_voc/class_names.txt"

with open(class_path) as f:
    class_names = [line.strip() for line in f.readlines()]


img = cv2.imread(img_path)

if img is None:
    print("Image not found:", img_path)


img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(img.shape)
plt.imshow(img)
# Out:
# (300, 300, 3)

# %%
# Create a color version of the mask
mask_color = imgviz.label2rgb(label=mask, label_names=class_names, font_size=15)

# Blend original image with mask color
overlay = (0.5 * img + 0.5 * mask_color).astype(np.uint8)

plt.imshow(overlay)
plt.title("Overlay: Image + Mask")
plt.axis("off")
plt.show()
